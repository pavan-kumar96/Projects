# %%
import pandas as pd
import numpy as np
import random

# %%
drinks = pd.read_csv('http://bit.ly/drinksbycountry')
movies = pd.read_csv('http://bit.ly/imdbratings')
orders = pd.read_csv('http://bit.ly/chiporders', sep='\t')
orders['item_price'] = orders.item_price.str.replace('$', '').astype('float')
stocks = pd.read_csv('http://bit.ly/smallstocks', parse_dates=['Date'])
titanic = pd.read_csv('http://bit.ly/kaggletrain')
ufo = pd.read_csv('http://bit.ly/uforeports', parse_dates=['Time'])

# %% [markdown]
# ### 25 Tricks on Pandas

# %% [markdown]
# ### 1. Show the installed versions:

# %%
pd.__version__
# Out:
# '0.25.1'

# %%
pd.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit           : None
# python           : 3.7.4.final.0
# python-bits      : 64
# OS               : Windows
# OS-release       : 8.1
# machine          : AMD64
# processor        : Intel64 Family 6 Model 69 Stepping 1, GenuineIntel
# byteorder        : little
# LC_ALL           : None
# LANG             : None
# LOCALE           : None.None
#
# pandas           : 0.25.1
# numpy            : 1.16.5
# pytz             : 2019.3
# dateutil         : 2.8.0
# pip              : 19.2.3
# setuptools       : 41.4.0
# Cython           : 0.29.13
# pytest           : 5.2.1
# hypothesis       : None
# sphinx           : 2.2.0
# blosc            : None
# feather          : None
# xlsxwriter       : 1.2.1
# lxml.etree       : 4.4.1
# html5lib         : 1.0.1
# pymysql          : None
# psycopg2         : None
# jinja2           : 2.10.3
# IPython          : 7.8.0
# pandas_datareader: None
# bs4              : 4.8.0
# bottleneck       : 1.2.1
# ...

# %% [markdown]
# ### 2. Creating the DataFrames :

# %%
# 1. by passing the dict
a = pd.DataFrame({"a":[1,2,3,4,5],"b": [10,11,12,13,14]})
a
# Out:
#    a   b
# 0  1  10
# 1  2  11
# 2  3  12
# 3  4  13
# 4  5  14

# %%
# by using the random fuction
import random
pd.DataFrame(np.random.rand(4,8))
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.341836  0.309610  0.656385  0.568935  0.379178  0.759055  0.200726
# 1  0.139229  0.895171  0.025069  0.470404  0.837719  0.096465  0.697648
# 2  0.123002  0.834787  0.020937  0.401707  0.374369  0.972272  0.752831
# 3  0.089520  0.558577  0.119809  0.256497  0.845886  0.193148  0.042077
#
#           7
# 0  0.490562
# 1  0.272004
# 2  0.266524
# 3  0.089660

# %%
# renaming the columns
import random
mf = pd.DataFrame(np.random.rand(4,8), columns = list("abcdefgh"))
mf
# Out:
#           a         b         c         d         e         f         g  \
# 0  0.749021  0.109743  0.146571  0.046839  0.760231  0.692206  0.655190
# 1  0.196078  0.256607  0.861922  0.379821  0.064168  0.279969  0.748594
# 2  0.263486  0.533378  0.630783  0.490408  0.183227  0.102197  0.132918
# 3  0.827363  0.017632  0.250430  0.564318  0.242470  0.207295  0.622607
#
#           h
# 0  0.685478
# 1  0.214199
# 2  0.102651
# 3  0.378565

# %%
# renaming the columns
import random
df = pd.DataFrame(np.random.rand(4,8), index = list("abcd"))

# %% [markdown]
# ### 3.Rename the columns

# %%
# 1. method 1
mf.rename(columns = {"a":"Age", "b":"Bar"})
# Out:
#         Age       Bar         c         d         e         f         g  \
# 0  0.749021  0.109743  0.146571  0.046839  0.760231  0.692206  0.655190
# 1  0.196078  0.256607  0.861922  0.379821  0.064168  0.279969  0.748594
# 2  0.263486  0.533378  0.630783  0.490408  0.183227  0.102197  0.132918
# 3  0.827363  0.017632  0.250430  0.564318  0.242470  0.207295  0.622607
#
#           h
# 0  0.685478
# 1  0.214199
# 2  0.102651
# 3  0.378565

# %%
# method 2
cols = ["age","aim","angry","animal"]
drinks = pd.read_csv("http://bit.ly/drinksbycountry", names = cols)
drinks
# Out:
#                                        age            aim  \
# country     beer_servings  spirit_servings  wine_servings
# Afghanistan 0                            0              0
# Albania     89                         132             54
# Algeria     25                           0             14
# Andorra     245                        138            312
# ...                                    ...            ...
# Venezuela   333                        100              3
# Vietnam     111                          2              1
# Yemen       6                            0              0
# Zambia      32                          19              4
# Zimbabwe    64                          18              4
#
#                                                   angry         animal
# country     beer_servings  total_litres_of_pure_alcohol      continent
# Afghanistan 0                                       0.0           Asia
# ...

# %%
drinks = pd.read_csv("http://bit.ly/drinksbycountry")
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
### sufix and prefix
print(mf.add_prefix('_x'))
print(mf.add_prefix('y_'))
# Out:
#         _xa       _xb       _xc       _xd       _xe       _xf       _xg  \
# 0  0.749021  0.109743  0.146571  0.046839  0.760231  0.692206  0.655190
# 1  0.196078  0.256607  0.861922  0.379821  0.064168  0.279969  0.748594
# 2  0.263486  0.533378  0.630783  0.490408  0.183227  0.102197  0.132918
# 3  0.827363  0.017632  0.250430  0.564318  0.242470  0.207295  0.622607
#
#         _xh
# 0  0.685478
# 1  0.214199
# 2  0.102651
# 3  0.378565
#         y_a       y_b       y_c       y_d       y_e       y_f       y_g  \
# 0  0.749021  0.109743  0.146571  0.046839  0.760231  0.692206  0.655190
# 1  0.196078  0.256607  0.861922  0.379821  0.064168  0.279969  0.748594
# 2  0.263486  0.533378  0.630783  0.490408  0.183227  0.102197  0.132918
# 3  0.827363  0.017632  0.250430  0.564318  0.242470  0.207295  0.622607
#
#         y_h
# 0  0.685478
# 1  0.214199
# 2  0.102651
# 3  0.378565

# %% [markdown]
# ### 4.Reverse the order the row

# %%
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
drinks[::-1]
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 192     Zimbabwe             64               18              4
# 191       Zambia             32               19              4
# 190        Yemen              6                0              0
# 189      Vietnam            111                2              1
# 188    Venezuela            333              100              3
# ..           ...            ...              ...            ...
# 4         Angola            217               57             45
# 3        Andorra            245              138            312
# 2        Algeria             25                0             14
# 1        Albania             89              132             54
# 0    Afghanistan              0                0              0
#
#      total_litres_of_pure_alcohol      continent
# 192                           4.7         Africa
# 191                           2.5         Africa
# ...

# %%
drinks.loc[::-1].reset_index(drop = True) # Reversing the order row wise
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0       Zimbabwe             64               18              4
# 1         Zambia             32               19              4
# 2          Yemen              6                0              0
# 3        Vietnam            111                2              1
# 4      Venezuela            333              100              3
# ..           ...            ...              ...            ...
# 188       Angola            217               57             45
# 189      Andorra            245              138            312
# 190      Algeria             25                0             14
# 191      Albania             89              132             54
# 192  Afghanistan              0                0              0
#
#      total_litres_of_pure_alcohol      continent
# 0                             4.7         Africa
# 1                             2.5         Africa
# ...

# %% [markdown]
# ### 5 . Reversing the order Column wise

# %%
drinks.loc[:,::-1]b
# Out:
#          continent  total_litres_of_pure_alcohol  wine_servings  \
# 0             Asia                           0.0              0
# 1           Europe                           4.9             54
# 2           Africa                           0.7             14
# 3           Europe                          12.4            312
# 4           Africa                           5.9             45
# ..             ...                           ...            ...
# 188  South America                           7.7              3
# 189           Asia                           2.0              1
# 190           Asia                           0.1              0
# 191         Africa                           2.5              4
# 192         Africa                           4.7              4
#
#      spirit_servings  beer_servings      country
# 0                  0              0  Afghanistan
# 1                132             89      Albania
# ...

# %% [markdown]
# ### 6.Select the data by datatypes

# %%
drinks.select_dtypes(include = ("object")) # For selecting the object type dtypes
# Out:
#          country      continent
# 0    Afghanistan           Asia
# 1        Albania         Europe
# 2        Algeria         Africa
# 3        Andorra         Europe
# 4         Angola         Africa
# ..           ...            ...
# 188    Venezuela  South America
# 189      Vietnam           Asia
# 190        Yemen           Asia
# 191       Zambia         Africa
# 192     Zimbabwe         Africa
#
# [193 rows x 2 columns]

# %%
drinks.select_dtypes(exclude = ("object")) # for selecting the datatypes excluding the object type
# Out:
#      beer_servings  spirit_servings  wine_servings  \
# 0                0                0              0
# 1               89              132             54
# 2               25                0             14
# 3              245              138            312
# 4              217               57             45
# ..             ...              ...            ...
# 188            333              100              3
# 189            111                2              1
# 190              6                0              0
# 191             32               19              4
# 192             64               18              4
#
#      total_litres_of_pure_alcohol
# 0                             0.0
# 1                             4.9
# 2                             0.7
# 3                            12.4
# 4                             5.9
# ..                            ...
# 188                           7.7
# 189                           2.0
# ...

# %%
drinks.select_dtypes(include = ("int64")) # for int dtypes
# Out:
#      beer_servings  spirit_servings  wine_servings
# 0                0                0              0
# 1               89              132             54
# 2               25                0             14
# 3              245              138            312
# 4              217               57             45
# ..             ...              ...            ...
# 188            333              100              3
# 189            111                2              1
# 190              6                0              0
# 191             32               19              4
# 192             64               18              4
#
# [193 rows x 3 columns]

# %%
drinks.select_dtypes(include = ("number")) # For number type dtypes
# Out:
#      beer_servings  spirit_servings  wine_servings  \
# 0                0                0              0
# 1               89              132             54
# 2               25                0             14
# 3              245              138            312
# 4              217               57             45
# ..             ...              ...            ...
# 188            333              100              3
# 189            111                2              1
# 190              6                0              0
# 191             32               19              4
# 192             64               18              4
#
#      total_litres_of_pure_alcohol
# 0                             0.0
# 1                             4.9
# 2                             0.7
# 3                            12.4
# 4                             5.9
# ..                            ...
# 188                           7.7
# 189                           2.0
# ...

# %%
drinks.select_dtypes(include = ["object", "int64","number","category"])  # For selected dtypes
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
drinks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
# country                         193 non-null object
# beer_servings                   193 non-null int64
# spirit_servings                 193 non-null int64
# wine_servings                   193 non-null int64
# total_litres_of_pure_alcohol    193 non-null float64
# continent                       193 non-null object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %% [markdown]
# ### 7.Coverting Strings into numbers

# %%
df = pd.DataFrame({'col_one':['1.1', '2.2', '3.3'],
                   'col_two':['4.4', '5.5', '6.6'],
                   'col_three':['7.7', '8.8', '-']})
df
# Out:
#   col_one col_two col_three
# 0     1.1     4.4       7.7
# 1     2.2     5.5       8.8
# 2     3.3     6.6         -

# %%
df.astype({"col_one":"float64"}) # but - for doing the same for col_three results in error becuse of "-"
# Out:
#    col_one col_two col_three
# 0      1.1     4.4       7.7
# 1      2.2     5.5       8.8
# 2      3.3     6.6         -

# %%
pd.to_numeric(df.col_three, errors= "coerce")
# Out:
# 0    7.7
# 1    8.8
# 2    NaN
# Name: col_three, dtype: float64

# %%
# to fill the null values we use fillna 
pd.to_numeric(df.col_three, errors = "coerce").fillna(0)
# Out:
# 0    7.7
# 1    8.8
# 2    0.0
# Name: col_three, dtype: float64

# %%
df = df.apply(pd.to_numeric , errors = "coerce").fillna(0)
df
# Out:
#    col_one  col_two  col_three
# 0      1.1      4.4        7.7
# 1      2.2      5.5        8.8
# 2      3.3      6.6        0.0

# %% [markdown]
# ### 8. Reduce the DataFrame size

# %%
drinks.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
# country                         193 non-null object
# beer_servings                   193 non-null int64
# spirit_servings                 193 non-null int64
# wine_servings                   193 non-null int64
# total_litres_of_pure_alcohol    193 non-null float64
# continent                       193 non-null object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 30.5 KB

# %%
# In order to reduce the DataFrame size select the required column
cols = ["beer_servings","country"]
drinks = pd.read_csv('http://bit.ly/drinksbycountry',usecols = cols)
drinks.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 2 columns):
# country          193 non-null object
# beer_servings    193 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 13.9 KB

# %%
# method 2 is to convert the object type into categorical colummn
cols = {"continent":"category"}
drinks = pd.read_csv('http://bit.ly/drinksbycountry',dtype = cols)
drinks.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
# country                         193 non-null object
# beer_servings                   193 non-null int64
# spirit_servings                 193 non-null int64
# wine_servings                   193 non-null int64
# total_litres_of_pure_alcohol    193 non-null float64
# continent                       193 non-null category
# dtypes: category(1), float64(1), int64(3), object(1)
# memory usage: 19.2 KB

# %% [markdown]
# ### 9 . Build a DataFrame with the multiple files (row wise)

# %%
from glob import glob
a = pd.read_clipboard()
b = pd.read_clipboard()
c = pd.read_clipboard()
a,b,c
# Out:
# (Empty DataFrame
#  Columns: [###, 9, ., Build, a, DataFrame, with, the, multiple, files, (row, wise)]
#  Index: [], Empty DataFrame
#  Columns: [###, 9, ., Build, a, DataFrame, with, the, multiple, files, (row, wise)]
#  Index: [], Empty DataFrame
#  Columns: [###, 9, ., Build, a, DataFrame, with, the, multiple, files, (row, wise)]
#  Index: [])

# %%
pd.concat([a,b,c], axis = 0, ignore_index= True)
# Out:
#          Date   Close    Volume Symbol
# 0  03-10-2016   31.50  14070500   CSCO
# 1  03-10-2016  112.52  21701800   AAPL
# 2  03-10-2016   57.42  19189500   MSFT
# 3  03-10-2016   31.50  14070500   CSCO
# 4  03-10-2016  112.52  21701800   AAPL
# 5  03-10-2016   57.42  19189500   MSFT
# 6  03-10-2016   31.50  14070500   CSCO
# 7  03-10-2016  112.52  21701800   AAPL
# 8  03-10-2016   57.42  19189500   MSFT

# %% [markdown]
# ### 10 . Build a DataFrame with the multiple files (column wise)

# %%
a = pd.read_clipboard()
a
# Out:
#        country  beer_servings  spirit_servings
# 0  Afghanistan              0                0
# 1      Albania             89              132
# 2      Algeria             25                0
# 3      Andorra            245              138
# 4       Angola            217               57

# %%
b = pd.read_clipboard()
b
# Out:
#    wine_servings  total_litres_of_pure_alcohol  continent Unnamed: 3
# 0              0                             0        0.0       Asia
# 1              1                            54        4.9     Europe
# 2              2                            14        0.7     Africa
# 3              3                           312       12.4     Europe
# 4              4                            45        5.9     Africa

# %%
c= pd.concat([a,b],axis = 0)
c
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#   Unnamed: 3  beer_servings  continent      country  spirit_servings  \
# 0        NaN            0.0        NaN  Afghanistan              0.0
# 1        NaN           89.0        NaN      Albania            132.0
# 2        NaN           25.0        NaN      Algeria              0.0
# 3        NaN          245.0        NaN      Andorra            138.0
# 4        NaN          217.0        NaN       Angola             57.0
# 0       Asia            NaN        0.0          NaN              NaN
# 1     Europe            NaN        4.9          NaN              NaN
# ...

# %% [markdown]
# ### 11 Clipboard, when u want copy the content in excel sheet and paste in notebook

# %%
pd.read_clipboard() ## copied the data from excel and wrote the code to get it pasted in the notebook
# it is very fast
# Out:
#    wine_servings  total_litres_of_pure_alcohol  continent Unnamed: 3
# 0              0                             0        0.0       Asia
# 1              1                            54        4.9     Europe
# 2              2                            14        0.7     Africa
# 3              3                           312       12.4     Europe
# 4              4                            45        5.9     Africa

# %% [markdown]
# ### 12.Split the DataFrame into 2 random subsets

# %%
len(movies)
# Out:
# 979

# %%
movie_1 = movies.sample(frac = 0.75, random_state = 1234)
movie_1
# Out:
#      star_rating                     title content_rating      genre  \
# 387          8.0           Midnight Cowboy              X      Drama
# 653          7.7                  Fearless          PG-13     Action
# 40           8.5            The Green Mile              R      Crime
# 913          7.5                  Suspiria              X     Horror
# 766          7.6        The Little Mermaid              G  Animation
# ..           ...                       ...            ...        ...
# 368          8.0        Planet of the Apes              G  Adventure
# 505          7.8                About Time              R      Drama
# 595          7.7  The Purple Rose of Cairo             PG     Comedy
# 940          7.4    Much Ado About Nothing          PG-13     Comedy
# 350          8.0         Shadow of a Doubt       APPROVED   Thriller
#
#      duration                                        actors_list
# 387       113  [u'Dustin Hoffman', u'Jon Voight', u'Sylvia Mi...
# ...

# %%
movie_2 = movies.drop(movie_1.index)
movie_2
# Out:
#      star_rating                                              title  \
# 1            9.2                                      The Godfather
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# ..           ...                                                ...
# 954          7.4                                              X-Men
# 960          7.4                                   The Way Way Back
# 968          7.4                                The English Patient
# 970          7.4                                        Wonder Boys
# 973          7.4                              The Cider House Rules
#
#     content_rating      genre  duration  \
# 1                R      Crime       175
# 3            PG-13     Action       152
# ...

# %%
len(movie_2)+len(movie_1)
# Out:
# 979

# %% [markdown]
# ### 13. Filter a DataFrame by multiple categories

# %%
movies.genre.unique()
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %%
movies.genre.value_counts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Thriller       5
# Sci-Fi         5
# Film-Noir      3
# Family         2
# Fantasy        1
# History        1
# Name: genre, dtype: int64

# %%
movies[(movies.genre == 'Action') |
       (movies.genre == 'Drama') |
       (movies.genre == 'Western')].head()
# Out:
#     star_rating                           title content_rating    genre  \
# 3           9.0                 The Dark Knight          PG-13   Action
# 5           8.9                    12 Angry Men      NOT RATED    Drama
# 6           8.9  The Good, the Bad and the Ugly      NOT RATED  Western
# 9           8.9                      Fight Club              R    Drama
# 11          8.8                       Inception          PG-13   Action
#
#     duration                                        actors_list
# 3        152  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 5         96  [u'Henry Fonda', u'Lee J. Cobb', u'Martin Bals...
# 6        161  [u'Clint Eastwood', u'Eli Wallach', u'Lee Van ...
# 9        139  [u'Brad Pitt', u'Edward Norton', u'Helena Bonh...
# 11       148  [u'Leonardo DiCaprio', u'Joseph Gordon-Levitt'...

# %%
movies[movies.genre.isin(["crime","Drama","Western"])]
# Out:
#      star_rating                            title content_rating    genre  \
# 5            8.9                     12 Angry Men      NOT RATED    Drama
# 6            8.9   The Good, the Bad and the Ugly      NOT RATED  Western
# 9            8.9                       Fight Club              R    Drama
# 13           8.8                     Forrest Gump          PG-13    Drama
# 16           8.7  One Flew Over the Cuckoo's Nest              R    Drama
# ..           ...                              ...            ...      ...
# 958          7.4               My Sister's Keeper          PG-13    Drama
# 968          7.4              The English Patient              R    Drama
# 970          7.4                      Wonder Boys              R    Drama
# 972          7.4                   Blue Valentine          NC-17    Drama
# 973          7.4            The Cider House Rules          PG-13    Drama
#
#      duration                                        actors_list
# ...

# %% [markdown]
# ### 14. Filter a DataFrame by largest categories¶

# %%
count = movies.genre.value_counts()
count.nlargest(3)
# Out:
# Drama     278
# Comedy    156
# Action    136
# Name: genre, dtype: int64

# %%
movies[movies.genre.isin(count.nlargest(3).index)]
# Out:
#      star_rating                                            title  \
# 3            9.0                                  The Dark Knight
# 5            8.9                                     12 Angry Men
# 9            8.9                                       Fight Club
# 11           8.8                                        Inception
# 12           8.8   Star Wars: Episode V - The Empire Strikes Back
# ..           ...                                              ...
# 971          7.4                               Death at a Funeral
# 972          7.4                                   Blue Valentine
# 973          7.4                            The Cider House Rules
# 974          7.4                                          Tootsie
# 976          7.4  Master and Commander: The Far Side of the World
#
#     content_rating   genre  duration  \
# 3            PG-13  Action       152
# 5        NOT RATED   Drama        96
# 9                R   Drama       139
# ...

# %% [markdown]
# ### 15. Handle missing values¶

# %%
ufo
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                      Time
# 0     1930-06-01 22:00:00
# 1     1930-06-30 20:00:00
# 2     1931-02-15 14:00:00
# 3     1931-06-01 13:00:00
# 4     1933-04-18 19:00:00
# ...

# %%
ufo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18241 entries, 0 to 18240
# Data columns (total 5 columns):
# City               18216 non-null object
# Colors Reported    2882 non-null object
# Shape Reported     15597 non-null object
# State              18241 non-null object
# Time               18241 non-null datetime64[ns]
# dtypes: datetime64[ns](1), object(4)
# memory usage: 712.7+ KB

# %%
ufo.isna().sum()
# Out:
# City                  25
# Colors Reported    15359
# Shape Reported      2644
# State                  0
# Time                   0
# dtype: int64

# %%
ufo.dropna(axis = 1)
# Out:
#       State                Time
# 0        NY 1930-06-01 22:00:00
# 1        NJ 1930-06-30 20:00:00
# 2        CO 1931-02-15 14:00:00
# 3        KS 1931-06-01 13:00:00
# 4        NY 1933-04-18 19:00:00
# ...     ...                 ...
# 18236    IL 2000-12-31 23:00:00
# 18237    IA 2000-12-31 23:00:00
# 18238    WI 2000-12-31 23:45:00
# 18239    WI 2000-12-31 23:45:00
# 18240    FL 2000-12-31 23:59:00
#
# [18241 rows x 2 columns]

# %%
ufo.sample(2)
# Out:
#               City Colors Reported Shape Reported State                Time
# 18211      Holyoke             NaN        DIAMOND    MA 2000-12-28 18:00:00
# 13825  Green River             NaN          OTHER    WY 1999-07-01 23:00:00

# %%
ufo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18241 entries, 0 to 18240
# Data columns (total 5 columns):
# City               18216 non-null object
# Colors Reported    2882 non-null object
# Shape Reported     15597 non-null object
# State              18241 non-null object
# Time               18241 non-null datetime64[ns]
# dtypes: datetime64[ns](1), object(4)
# memory usage: 712.7+ KB

# %%
ufo.dropna(thresh= len(ufo)*0.9, axis = 1) # 90% of data containing columns
# Out:
#                        City State                Time
# 0                    Ithaca    NY 1930-06-01 22:00:00
# 1               Willingboro    NJ 1930-06-30 20:00:00
# 2                   Holyoke    CO 1931-02-15 14:00:00
# 3                   Abilene    KS 1931-06-01 13:00:00
# 4      New York Worlds Fair    NY 1933-04-18 19:00:00
# ...                     ...   ...                 ...
# 18236            Grant Park    IL 2000-12-31 23:00:00
# 18237           Spirit Lake    IA 2000-12-31 23:00:00
# 18238           Eagle River    WI 2000-12-31 23:45:00
# 18239           Eagle River    WI 2000-12-31 23:45:00
# 18240                  Ybor    FL 2000-12-31 23:59:00
#
# [18241 rows x 3 columns]

# %% [markdown]
# ### 16. Split a string into multiple columns¶

# %%
df = pd.DataFrame({'name':['John Arthur Doe', 'Jane Ann Smith'],
                   'location':['Los Angeles, CA', 'Washington, DC']})
df
# Out:
#               name         location
# 0  John Arthur Doe  Los Angeles, CA
# 1   Jane Ann Smith   Washington, DC

# %%
df["city"] = df.location.str.split(",", expand = True)[0]
df
# Out:
#               name         location         city
# 0  John Arthur Doe  Los Angeles, CA  Los Angeles
# 1   Jane Ann Smith   Washington, DC   Washington

# %% [markdown]
# ### 18. Aggregate by multiple functions¶

# %%
orders
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
orders.groupby("order_id").item_price.sum()
# Out:
# order_id
# 1       11.56
# 2       16.98
# 3       12.67
# 4       21.00
# 5       13.70
#         ...
# 1830    23.00
# 1831    12.90
# 1832    13.20
# 1833    23.50
# 1834    28.75
# Name: item_price, Length: 1834, dtype: float64

# %%
a = orders.groupby("order_id").item_price.agg(["sum","mean"])
a
# Out:
#             sum       mean
# order_id
# 1         11.56   2.890000
# 2         16.98  16.980000
# 3         12.67   6.335000
# 4         21.00  10.500000
# 5         13.70   6.850000
# ...         ...        ...
# 1830      23.00  11.500000
# 1831      12.90   4.300000
# 1832      13.20   6.600000
# 1833      23.50  11.750000
# 1834      28.75   9.583333
#
# [1834 rows x 2 columns]

# %% [markdown]
# ### 19. Combine the output of an aggregation with a DataFrame¶

# %%
orders
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
len(a)
# Out:
# 1834

# %%
len(orders.item_price)
# Out:
# 4622

# %%
tranform_data =orders.groupby("order_id").item_price.transform("sum")

# %%
orders["Total_value "] = tranform_data
len(tranform_data)
# Out:
# 4622
